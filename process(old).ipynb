# %%
import pandas as pd
import numpy as np

# %%
test_1  = pd.read_csv('output/ping_tcp_1_processed.csv')
test_2  = pd.read_csv('output/ping_tcp_2_processed.csv')
test_3  = pd.read_csv('output/ping_tcp_3_processed.csv')

# %%
throughput_1 = np.sum(test_1['Length'] * 8) / 301.851
throughput_2 = np.sum(test_2['Length'] * 8) / 311.664
throughput_3 = np.sum(test_3['Length'] * 8) / 302.140

# %%
packet_loss = 0

# %%
delay_avg_1 = np.average(test_1['Delay1'].dropna())
delay_avg_2 = np.average(test_2['Delay1'].dropna())
delay_avg_3 = np.average(test_3['Delay1'].dropna())

# %%
print(delay_avg_1)
# Out:
# 0.5270699434325745

# %%
total_delay_1 = np.sum(test_1['Delay1'].dropna())
total_delay_2 = np.sum(test_2['Delay1'].dropna())
total_delay_3 = np.sum(test_3['Delay1'].dropna())

# %%
total_delay_variance_1 = np.var(test_1['Delay1'].dropna())
total_delay_variance_2 = np.var(test_2['Delay1'].dropna())
total_delay_variance_3 = np.var(test_3['Delay1'].dropna())

# %%
jitter_1 = np.average(test_1['Selisih'].dropna())
jitter_2 = np.average(test_2['Selisih'].dropna())
jitter_3 = np.average(test_3['Selisih'].dropna())

# %%
output_df = pd.DataFrame({
    'Test': ['Test 1', 'Test 2', 'Test 3'],
    'Throughput (bps)': [throughput_1, throughput_2, throughput_3],
    'Packet Loss (%)': [packet_loss, packet_loss, packet_loss],
    'Average Delay (s)': [delay_avg_1, delay_avg_2, delay_avg_3],
    'Total Delay (s)': [total_delay_1, total_delay_2, total_delay_3],
    # 'Delay Variance (s^2)': [total_delay_variance_1, total_delay_variance_2, total_delay_variance_3],
    'Jitter (s)': [jitter_1, jitter_2, jitter_3]
})

output_df.to_csv('output/ping_summary.csv', index=False)
